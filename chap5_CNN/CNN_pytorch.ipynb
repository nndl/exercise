# %%
import os
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import torchvision
import torch.nn.functional as F
import numpy as np
learning_rate = 1e-4
keep_prob_rate = 0.7 #
max_epoch = 3
BATCH_SIZE = 50

DOWNLOAD_MNIST = False
if not(os.path.exists('./mnist/')) or not os.listdir('./mnist/'):
    # not mnist dir or mnist is empyt dir
    DOWNLOAD_MNIST = True


train_data = torchvision.datasets.MNIST(root='./mnist/',train=True, transform=torchvision.transforms.ToTensor(), download=DOWNLOAD_MNIST,)
train_loader = Data.DataLoader(dataset = train_data ,batch_size= BATCH_SIZE ,shuffle= True)

test_data = torchvision.datasets.MNIST(root = './mnist/',train = False)

test_x = Variable(torch.unsqueeze(test_data.test_data,dim  = 1)).type(torch.FloatTensor)[:500]/255.
test_y = test_data.test_labels[:500].numpy()

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(
                # patch 7 * 7 ; 1  in channels ; 32 out channels ; ; stride is 1
                # padding style is same(that means the convolution opration's input and output have the same size)
                in_channels=1,  
                out_channels=32,
                kernel_size=7,
                stride=1,
                padding=3,
            ),
            nn.ReLU(),        # activation function
            nn.MaxPool2d(2),  # pooling operation
        )
        self.conv2 = nn.Sequential( # ???
            # line 1 : convolution function, patch 5*5 , 32 in channels ;64 out channels; padding style is same; stride is 1
            # line 2 : choosing your activation funciont
            # line 3 : pooling operation function.
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.out1 = nn.Linear( 7*7*64 , 1024 , bias= True)   # full connection layer one
        self.dropout = nn.Dropout(keep_prob_rate)
        self.out2 = nn.Linear(1024,10,bias=True)



    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view(-1, 64 * 7 * 7)  # flatten the output of coonv2 to (batch_size ,64 * 7 * 7)
        out1 = self.out1(x)
        out1 = F.relu(out1)
        out1 = self.dropout(out1)
        out2 = self.out2(out1)
        output = F.softmax(out2, -1)
        return output


def test(cnn):
    global prediction
    with torch.no_grad():
        y_pre = cnn(test_x)
        _,pre_index= torch.max(y_pre,1)
        pre_index= pre_index.view(-1)
        prediction = pre_index.data.numpy()
        correct  = np.sum(prediction == test_y)
        return correct / 500.0


def train(cnn):
    loss_func = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(cnn.parameters(), lr=learning_rate)
    for epoch in range(max_epoch):
        for step, (x_, y_) in enumerate(train_loader):
            x ,y= Variable(x_),Variable(y_)
            output = cnn(x)  
            loss = loss_func(output,y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if step != 0 and step % 20 ==0:
                print("=" * 10,step,"="*5,"="*5, "test accuracy is ",test(cnn) ,"=" * 10 )

# %%
print(torch.__version__)
cnn = CNN()
train(cnn)
# Out:
# 2.2.0
# ========== 20 ===== ===== test accuracy is  0.392 ==========
# ========== 40 ===== ===== test accuracy is  0.332 ==========
# ========== 60 ===== ===== test accuracy is  0.49 ==========
# ========== 80 ===== ===== test accuracy is  0.542 ==========
# ========== 100 ===== ===== test accuracy is  0.61 ==========
# ========== 120 ===== ===== test accuracy is  0.636 ==========
# ========== 140 ===== ===== test accuracy is  0.68 ==========
# ========== 160 ===== ===== test accuracy is  0.708 ==========
# ========== 180 ===== ===== test accuracy is  0.718 ==========
# ========== 200 ===== ===== test accuracy is  0.75 ==========
# ========== 220 ===== ===== test accuracy is  0.784 ==========
# ========== 240 ===== ===== test accuracy is  0.828 ==========
# ========== 260 ===== ===== test accuracy is  0.812 ==========
# ========== 280 ===== ===== test accuracy is  0.836 ==========
# ========== 300 ===== ===== test accuracy is  0.846 ==========
# ========== 320 ===== ===== test accuracy is  0.846 ==========
# ========== 340 ===== ===== test accuracy is  0.864 ==========
# ========== 360 ===== ===== test accuracy is  0.856 ==========
# ========== 380 ===== ===== test accuracy is  0.856 ==========
# ========== 400 ===== ===== test accuracy is  0.894 ==========
# ========== 420 ===== ===== test accuracy is  0.896 ==========
# ========== 440 ===== ===== test accuracy is  0.9 ==========
# ========== 460 ===== ===== test accuracy is  0.902 ==========
# ========== 480 ===== ===== test accuracy is  0.876 ==========
# ========== 500 ===== ===== test accuracy is  0.9 ==========
# ========== 520 ===== ===== test accuracy is  0.906 ==========
# ========== 540 ===== ===== test accuracy is  0.904 ==========
# ========== 560 ===== ===== test accuracy is  0.912 ==========
# ========== 580 ===== ===== test accuracy is  0.888 ==========
# ========== 600 ===== ===== test accuracy is  0.886 ==========
# ========== 620 ===== ===== test accuracy is  0.918 ==========
# ========== 640 ===== ===== test accuracy is  0.932 ==========
# ========== 660 ===== ===== test accuracy is  0.916 ==========
# ========== 680 ===== ===== test accuracy is  0.914 ==========
# ========== 700 ===== ===== test accuracy is  0.924 ==========
# ========== 720 ===== ===== test accuracy is  0.91 ==========
# ========== 740 ===== ===== test accuracy is  0.924 ==========
# ========== 760 ===== ===== test accuracy is  0.932 ==========
# ========== 780 ===== ===== test accuracy is  0.934 ==========
# ========== 800 ===== ===== test accuracy is  0.932 ==========
# ========== 820 ===== ===== test accuracy is  0.934 ==========
# ========== 840 ===== ===== test accuracy is  0.932 ==========
# ========== 860 ===== ===== test accuracy is  0.934 ==========
# ========== 880 ===== ===== test accuracy is  0.932 ==========
# ========== 900 ===== ===== test accuracy is  0.934 ==========
# ========== 920 ===== ===== test accuracy is  0.924 ==========
# ========== 940 ===== ===== test accuracy is  0.936 ==========
# ========== 960 ===== ===== test accuracy is  0.944 ==========
# ========== 980 ===== ===== test accuracy is  0.942 ==========
# ========== 1000 ===== ===== test accuracy is  0.94 ==========
# ========== 1020 ===== ===== test accuracy is  0.938 ==========
# ========== 1040 ===== ===== test accuracy is  0.938 ==========
# ========== 1060 ===== ===== test accuracy is  0.942 ==========
# ========== 1080 ===== ===== test accuracy is  0.95 ==========
# ========== 1100 ===== ===== test accuracy is  0.946 ==========
# ========== 1120 ===== ===== test accuracy is  0.942 ==========
# ========== 1140 ===== ===== test accuracy is  0.938 ==========
# ========== 1160 ===== ===== test accuracy is  0.952 ==========
# ========== 1180 ===== ===== test accuracy is  0.95 ==========
# ========== 20 ===== ===== test accuracy is  0.952 ==========
# ========== 40 ===== ===== test accuracy is  0.95 ==========
# ========== 60 ===== ===== test accuracy is  0.952 ==========
# ========== 80 ===== ===== test accuracy is  0.942 ==========
# ========== 100 ===== ===== test accuracy is  0.954 ==========
# ========== 120 ===== ===== test accuracy is  0.954 ==========
# ========== 140 ===== ===== test accuracy is  0.956 ==========
# ========== 160 ===== ===== test accuracy is  0.966 ==========
# ========== 180 ===== ===== test accuracy is  0.944 ==========
# ========== 200 ===== ===== test accuracy is  0.958 ==========
# ========== 220 ===== ===== test accuracy is  0.956 ==========
# ========== 240 ===== ===== test accuracy is  0.94 ==========
# ========== 260 ===== ===== test accuracy is  0.958 ==========
# ========== 280 ===== ===== test accuracy is  0.96 ==========
# ========== 300 ===== ===== test accuracy is  0.948 ==========
# ========== 320 ===== ===== test accuracy is  0.952 ==========
# ========== 340 ===== ===== test accuracy is  0.954 ==========
# ========== 360 ===== ===== test accuracy is  0.966 ==========
# ========== 380 ===== ===== test accuracy is  0.96 ==========
# ========== 400 ===== ===== test accuracy is  0.966 ==========
# ========== 420 ===== ===== test accuracy is  0.936 ==========
# ========== 440 ===== ===== test accuracy is  0.96 ==========
# ========== 460 ===== ===== test accuracy is  0.96 ==========
# ========== 480 ===== ===== test accuracy is  0.958 ==========
# ========== 500 ===== ===== test accuracy is  0.958 ==========
# ========== 520 ===== ===== test accuracy is  0.962 ==========
# ========== 540 ===== ===== test accuracy is  0.958 ==========
# ========== 560 ===== ===== test accuracy is  0.956 ==========
# ========== 580 ===== ===== test accuracy is  0.95 ==========
# ========== 600 ===== ===== test accuracy is  0.962 ==========
# ========== 620 ===== ===== test accuracy is  0.966 ==========
# ========== 640 ===== ===== test accuracy is  0.962 ==========
# ========== 660 ===== ===== test accuracy is  0.962 ==========
# ========== 680 ===== ===== test accuracy is  0.964 ==========
# ========== 700 ===== ===== test accuracy is  0.958 ==========
# ========== 720 ===== ===== test accuracy is  0.972 ==========
# ========== 740 ===== ===== test accuracy is  0.968 ==========
# ========== 760 ===== ===== test accuracy is  0.968 ==========
# ========== 780 ===== ===== test accuracy is  0.964 ==========
# ========== 800 ===== ===== test accuracy is  0.966 ==========
# ========== 820 ===== ===== test accuracy is  0.962 ==========
# ========== 840 ===== ===== test accuracy is  0.97 ==========
# ========== 860 ===== ===== test accuracy is  0.97 ==========
# ========== 880 ===== ===== test accuracy is  0.962 ==========
# ========== 900 ===== ===== test accuracy is  0.976 ==========
# ========== 920 ===== ===== test accuracy is  0.968 ==========
# ========== 940 ===== ===== test accuracy is  0.96 ==========
# ========== 960 ===== ===== test accuracy is  0.97 ==========
# ========== 980 ===== ===== test accuracy is  0.966 ==========
# ========== 1000 ===== ===== test accuracy is  0.97 ==========
# ========== 1020 ===== ===== test accuracy is  0.974 ==========
# ========== 1040 ===== ===== test accuracy is  0.966 ==========
# ========== 1060 ===== ===== test accuracy is  0.968 ==========
# ========== 1080 ===== ===== test accuracy is  0.966 ==========
# ========== 1100 ===== ===== test accuracy is  0.98 ==========
# ========== 1120 ===== ===== test accuracy is  0.97 ==========
# ========== 1140 ===== ===== test accuracy is  0.972 ==========
# ========== 1160 ===== ===== test accuracy is  0.964 ==========
# ========== 1180 ===== ===== test accuracy is  0.966 ==========
# ========== 20 ===== ===== test accuracy is  0.97 ==========
# ========== 40 ===== ===== test accuracy is  0.97 ==========
# ========== 60 ===== ===== test accuracy is  0.968 ==========
# ========== 80 ===== ===== test accuracy is  0.972 ==========
# ========== 100 ===== ===== test accuracy is  0.972 ==========
# ========== 120 ===== ===== test accuracy is  0.972 ==========
# ========== 140 ===== ===== test accuracy is  0.97 ==========
# ========== 160 ===== ===== test accuracy is  0.978 ==========
# ========== 180 ===== ===== test accuracy is  0.972 ==========
# ========== 200 ===== ===== test accuracy is  0.974 ==========
# ========== 220 ===== ===== test accuracy is  0.97 ==========
# ========== 240 ===== ===== test accuracy is  0.97 ==========
# ========== 260 ===== ===== test accuracy is  0.972 ==========
# ========== 280 ===== ===== test accuracy is  0.968 ==========
# ========== 300 ===== ===== test accuracy is  0.976 ==========
# ========== 320 ===== ===== test accuracy is  0.976 ==========
# ========== 340 ===== ===== test accuracy is  0.966 ==========
# ========== 360 ===== ===== test accuracy is  0.97 ==========
# ========== 380 ===== ===== test accuracy is  0.97 ==========
# ========== 400 ===== ===== test accuracy is  0.974 ==========
# ========== 420 ===== ===== test accuracy is  0.964 ==========
# ========== 440 ===== ===== test accuracy is  0.968 ==========
# ========== 460 ===== ===== test accuracy is  0.964 ==========
# ========== 480 ===== ===== test accuracy is  0.97 ==========
# ========== 500 ===== ===== test accuracy is  0.98 ==========
# ========== 520 ===== ===== test accuracy is  0.964 ==========
# ========== 540 ===== ===== test accuracy is  0.97 ==========
# ========== 560 ===== ===== test accuracy is  0.972 ==========
# ========== 580 ===== ===== test accuracy is  0.968 ==========
# ========== 600 ===== ===== test accuracy is  0.972 ==========
# ========== 620 ===== ===== test accuracy is  0.978 ==========
# ========== 640 ===== ===== test accuracy is  0.958 ==========
# ========== 660 ===== ===== test accuracy is  0.964 ==========
# ========== 680 ===== ===== test accuracy is  0.97 ==========
# ========== 700 ===== ===== test accuracy is  0.966 ==========
# ========== 720 ===== ===== test accuracy is  0.968 ==========
# ========== 740 ===== ===== test accuracy is  0.976 ==========
# ========== 760 ===== ===== test accuracy is  0.968 ==========
# ========== 780 ===== ===== test accuracy is  0.976 ==========
# ========== 800 ===== ===== test accuracy is  0.968 ==========
# ========== 820 ===== ===== test accuracy is  0.968 ==========
# ========== 840 ===== ===== test accuracy is  0.978 ==========
# ========== 860 ===== ===== test accuracy is  0.964 ==========
# ========== 880 ===== ===== test accuracy is  0.968 ==========
# ========== 900 ===== ===== test accuracy is  0.972 ==========
# ========== 920 ===== ===== test accuracy is  0.966 ==========
# ========== 940 ===== ===== test accuracy is  0.972 ==========
# ========== 960 ===== ===== test accuracy is  0.978 ==========
# ========== 980 ===== ===== test accuracy is  0.974 ==========
# ========== 1000 ===== ===== test accuracy is  0.976 ==========
# ========== 1020 ===== ===== test accuracy is  0.968 ==========
# ========== 1040 ===== ===== test accuracy is  0.976 ==========
# ========== 1060 ===== ===== test accuracy is  0.976 ==========
# ========== 1080 ===== ===== test accuracy is  0.976 ==========
# ========== 1100 ===== ===== test accuracy is  0.978 ==========
# ========== 1120 ===== ===== test accuracy is  0.982 ==========
# ========== 1140 ===== ===== test accuracy is  0.978 ==========
# ========== 1160 ===== ===== test accuracy is  0.974 ==========
# ========== 1180 ===== ===== test accuracy is  0.968 ==========
